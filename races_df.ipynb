# %%
#import pandas
import pandas as pd

# %%
horse_df = pd.read_csv("runner_result.csv")

# %%
horse_df
# Out:
#        meetingName             meetingDate  raceNumber  runnerNumber  \
# 0      STONY CREEK  01/02/2022 12:00:00 AM           1             3
# 1      STONY CREEK  01/02/2022 12:00:00 AM           1            11
# 2      STONY CREEK  01/02/2022 12:00:00 AM           1             2
# 3      STONY CREEK  01/02/2022 12:00:00 AM           1             9
# 4      STONY CREEK  01/02/2022 12:00:00 AM           1             8
# ...            ...                     ...         ...           ...
# 13183         YORK  19/05/2022 12:00:00 AM           8             5
# 13184         YORK  19/05/2022 12:00:00 AM           8             4
# 13185         YORK  19/05/2022 12:00:00 AM           8             7
# 13186         YORK  19/05/2022 12:00:00 AM           8             6
# 13187         YORK  19/05/2022 12:00:00 AM           8             1
#
#        Unnamed: 0  location weatherCondition trackCondition  \
# 0             0.0       NaN            OCAST          GOOD3
# ...

# %%
horse_df.columns
# Out:
# Index(['meetingName', 'meetingDate', 'raceNumber', 'runnerNumber',
#        'Unnamed: 0', 'location', 'weatherCondition', 'trackCondition',
#        'raceName', 'raceStartTime', 'raceDistance', 'trackDirection',
#        'raceClassConditions', 'runnerName', 'riderName', 'finishingPosition',
#        'FixedWinOpen', 'FixedWinClose', 'overall (runner starts)',
#        'track (runner starts)', 'firm (runner starts)', 'good (runner starts)',
#        'dead (runner starts)', 'slow (runner starts)', 'soft (runner starts)',
#        'heavy (runner starts)', 'distance (runner starts)',
#        'classSame (runner starts)', 'classStronger (runner starts)',
#        'firstUp (runner starts)', 'secondUp (runner starts)',
#        'trackDistance (runner starts)', 'overall (runner wins)',
#        'track (runner wins)', 'firm (runner wins)', 'good (runner wins)',
#        'dead (runner wins)', 'slow (runner wins)', 'soft (runner wins)',
#        'heavy (runner wins)', 'distance (runner wins)',
# ...

# %%
new_df = horse_df["riderName", "track (runner wins)"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/envs/PythonData38/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('riderName', 'track (runner wins)')
#
# ...

# %%
new_df
# Out:
# 0                 D.LANE
# 1        Sheridan Clarke
# 2         Jason Maskiell
# 3           Craig Newitt
# 4           Beau Mertens
#               ...
# 13183          B.PARNHAM
# 13184         B.RAWILLER
# 13185           J.TURNER
# 13186            K.YUILL
# 13187        J.AZZOPARDI
# Name: riderName, Length: 13188, dtype: object
